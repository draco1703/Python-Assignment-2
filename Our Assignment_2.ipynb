# %% [markdown]
# # Assignment 2: Plottings
#
# This assignment is about plotting.

# %% [markdown]
# Create data visualizations comparing different groups of Copenhagen citizens. For example:
# 1. Create a bar plot that shows distribution of german and british citizens in terms of age.
# 2. How many French are there compared to Germans and how are they distributed over various neighbourhoods?
# 3. Create a pie chart showing the 5 major citizen groups of age between 20-65
# 4. (red assignment) Try to add the markers that you get from the GeoJson response exercise 2 to the map.
#
# **Hint**: Make use of https://www.dst.dk/da/Statistik/dokumentation/Times/forebyggelsesregistret/statkode.aspx to find the citizenship category numbers.
#
# For exercise 4 make use of:
# ```
# folium.Marker(
# [12.578995447902946, 55.713167699503515],
# popup='some text here'
# ).add_to(map_osm)
# ```
# and follow the documentation at http://folium.readthedocs.io/en/latest/quickstart.html

# %% [markdown]
# Create a bar plot that shows distribution of german and british citizens in terms of age.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import kkdata

no_germans_per_age = {}
no_brits_per_age = {}
neighbourhoods = kkdata.STATISTICS[2015].keys()
age_range = set([])
for n in neighbourhoods:
    age_range.update(kkdata.STATISTICS[2015][n].keys())

for n in neighbourhoods:
    for age in age_range:
        if age in kkdata.STATISTICS[2015][n].keys():
            c_codes = set(kkdata.STATISTICS[2015][n][age].keys())
            if 5180 in c_codes:
                no_germans_per_age.setdefault(age, 0)
                no_germans_per_age[age] += kkdata.STATISTICS[2015][n][age][5180]
            if 5170 in c_codes:
                no_brits_per_age.setdefault(age, 0)
                no_brits_per_age[age] += kkdata.STATISTICS[2015][n][age][5170]

plt.bar(no_brits_per_age.keys(), no_brits_per_age.values(), color="blue")
plt.bar(no_germans_per_age.keys(), no_germans_per_age.values(), color="red")
plt.ylabel("Number of citizens")
plt.xlabel("Ages")
plt.title("Number of brits(blue) and germans(red)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Number of brits(blue) and germans(red)')

# %% [markdown]
# How many French are there compared to Germans and how are they distributed over various neighbourhoods?

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import kkdata

no_germans = {}
no_french = {}
neighbourhoods = kkdata.STATISTICS[2015].keys()
age_range = set([])
for n in neighbourhoods:
    age_range.update(kkdata.STATISTICS[2015][n].keys())

for n in neighbourhoods:
    for age in age_range:
        if age in kkdata.STATISTICS[2015][n].keys():
            c_codes = set(kkdata.STATISTICS[2015][n][age].keys())
            if 5180 in c_codes:
                no_germans.setdefault(n, 0)
                no_germans[n] += kkdata.STATISTICS[2015][n][age][5180]
            if 5130 in c_codes:
                no_french.setdefault(n, 0)
                no_french[n] += kkdata.STATISTICS[2015][n][age][5130]

plt.bar(no_germans.keys(), no_germans.values())
plt.bar(no_french.keys(), no_french.values())
plt.xlabel("Neighbourhoods")
plt.ylabel("Number of citizens")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Number of citizens')

# %% [markdown]
# Create a pie chart showing the 5 major citizen groups of age between 20-65

# %%
[insert code here]

# %% [markdown]
# (red assignment) Try to add the markers that you get from the GeoJson response exercise 2 to the map.

# %%
[insert code here]
